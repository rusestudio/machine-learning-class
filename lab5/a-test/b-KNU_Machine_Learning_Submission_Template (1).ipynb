# %% [markdown]
# # Instruction

# %% [markdown]
# ## Basic Policy

# %% [markdown]
# * 이 템플릿을 **파일 - Drive에 사본 저장** 또는 **파일 - 다운로드 - \*.ipynb 다운로드** 한 후 과제를 수행할 것
# * 템플릿에 명시된 **Installing Dependencies**, **Data Load**, **Do Your Own Jobs!**, **Generating Final Submissions**, **Public Score** 의 안내를 확인하여 코드를 작성할 것
# * 템플릿에 있는 사항은 **삭제하지 말 것**
# * 그 외 과제 수행에 있어 필요한 별도의 섹션, 마크다운 셀, 코드 셀 등은 **사이 사이에 자유롭게 추가해도 좋음**

# %% [markdown]
# ## 0-Credit Criteria

# %% [markdown]
# 다음과 같은 사항을 어길 시 **0점 처리**됨
#
# * Kaggle Leaderboard에 본인의 제출 결과가 나타나지 않을 시
# * 이루리에 노트북 파일(*.ipynb) 미제출 또는 지연 제출 시
# * 노트북 파일에 기록된 모든 코드 셀을 **전체 실행 (예. Colab의 경우 *런타임-모두 실행*)했을 때 오류가 발생하여 마지막 코드 셀까지 실행이 되지 않는** 경우
# * 노트북 내에 **명시되지 않은 별도의 소스 코드 및 의존성 라이브러리를 사용**하는 경우
#     * 과제 수행에 필요한 라이브러리 설치 명령은 노트북 내에서 명시해야 함
#     * 별도의 파이썬 코드를 파일로 저장하여 사용하지 말 것
#     * 필요한 모든 코드는 노트북 내에서 구현되어야 함
# * 과제에서 제공한 데이터 이외의 **별도의 데이터를 사용**하는 경우
# * 노트북 파일 내에서 처음부터 끝까지 훈련된 기계 학습 모델이 아닌 **다른 기계 학습 모델을 사용 (예. 전이 학습, 파인 튜닝 등)** 하는 경우
# * 노트북 파일 제출 템플릿에서 안내된 사항을 따르지 않은 경우

# %% [markdown]
# ## The Use of the LLM and Coding Agent

# %% [markdown]
# * 본 과제를 수행함에 있어 LLM 또는 코딩 에이전트는 **자유롭게 활용해도 좋음**
# * 단, 이 노트북 내에서 LLM, 코딩 에이전트 등을 호출하는 것은 금지되며, 오직 데이터 전처리, 기계 학습 모델 훈련, 제출 결과 생성 등에 관련된 코드만 존재해야 함

# %% [markdown]
# # Installing Dependencies

# %% [markdown]
# 과제를 수행함에 있어 설치해야 하는 의존성 라이브러리 등이 있을 시 아래 코드 셀에 설치 명령을 작성할 것
#
# * 예. *scikit-learn* 및 *altair* 설치
# ```shell
# %pip install scikit-learn altair
# ```

# %%
# 라이브러리 설치 코드 작성

# %% [markdown]
# # Data Load

# %% [markdown]
# 과제에서 활용하는 데이터를 Kaggle API 활용 또는 다운로드 후 불러오기를 통해서 다음과 같은 변수에 저장:
# * 훈련 입력 데이터 (예. **train-data.csv**): **TRAIN_DATA**
# * 훈련 레이블 데이터 (예. **train-label.csv**): **TRAIN_LABEL**
# * 테스트 입력 데이터 (예. **test-data.csv**): **TEST_DATA**
# * 테스트 레이블 데이터 (예. **test-label.csv**): **TEST_LABEL**
#
# * 예. 다운로드 후 불러오기 시
# ```python
# import pandas as pd
#
#
# TRAIN_DATA = pd.read_csv('train-data.csv', index_col='id')
# TRAIN_LABEL = pd.read_csv('train-label.csv', index_col='id')
# TEST_DATA = pd.read_csv('test-data.csv', index_col='id')
# TEST_LABEL = pd.read_csv('test-label.csv', index_col='id')
# ```

# %%
# 데이터 로드 코드 작성


TRAIN_DATA = ...
TRAIN_LABEL = ...
TEST_DATA = ...
TEST_LABEL = ...

# %% [markdown]
# # Do Your Own Jobs!

# %% [markdown]
# 최종적인 Kaggle 제출물 생성을 위해 필요한 모든 일(예. 데이터 탐색, 전처리, 특성값 추출/선택/제거, 모델 훈련, 초매개변수 최적화 등)을 **자유롭게, 필요한 만큼 코드/마크다운 셀을 생성하여** 작성

# %%
# 최종 제출 결과를 생성하기 위한 모든 작업들을 자유롭게 작성

# %% [markdown]
# # Generating Final Submissions

# %% [markdown]
#  Kaggle 제출물인 **csv 파일**을 생성하는 코드를 아래에 작성할 것
#
# * 예.
# ```python
# YOUR_PREDICTIONS.to_csv('submission-v1.csv')
# ```

# %%
# Kaggle 제출물 생성 코드 작성
